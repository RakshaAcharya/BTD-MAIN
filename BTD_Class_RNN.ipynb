# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
from tensorflow.keras.utils import plot_model
from keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D,BatchNormalization, Flatten, Dense, Dropout

# %%
labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/MRI BTD Classification dataset','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/MRI BTD Classification dataset','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:33<00:00, 24.83it/s]
# 100%|██████████| 395/395 [00:08<00:00, 44.70it/s]
# 100%|██████████| 822/822 [00:22<00:00, 36.69it/s]
# 100%|██████████| 837/837 [00:32<00:00, 25.74it/s]
# 100%|██████████| 100/100 [00:03<00:00, 26.11it/s]
# 100%|██████████| 105/105 [00:03<00:00, 32.45it/s]
# 100%|██████████| 115/115 [00:03<00:00, 33.17it/s]
# 100%|██████████| 74/74 [00:46<00:00,  1.58it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
X_train.shape
# Out:
# (2946, 150, 150, 3)

# %%
X_test.shape
# Out:
# (328, 150, 150, 3)

# %%
y_train.shape
# Out:
# (2946,)

# %%
y_test.shape
# Out:
# (328,)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
y_test_labels = np.argmax(y_test, axis=1)

# Find unique class labels
unique_labels = np.unique(y_test_labels)

print("Unique class labels:", unique_labels)
# Out:
# Unique class labels: [0 1 2 3]

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001, mode='auto',verbose=1)

# %%
plot_model(model, show_shapes=True, dpi=150)

# Display the plot
plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.787384 to fit

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =5, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/5
# 83/83 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.8189
# Epoch 1: val_accuracy improved from -inf to 0.86102, saving model to effnet.keras
# 83/83 [==============================] - 57s 197ms/step - loss: 0.4847 - accuracy: 0.8189 - val_loss: 0.4024 - val_accuracy: 0.8610 - lr: 0.0010
# Epoch 2/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9370
# Epoch 2: val_accuracy improved from 0.86102 to 0.87119, saving model to effnet.keras
# 83/83 [==============================] - 12s 144ms/step - loss: 0.1928 - accuracy: 0.9370 - val_loss: 0.3317 - val_accuracy: 0.8712 - lr: 0.0010
# Epoch 3/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9578
# Epoch 3: val_accuracy improved from 0.87119 to 0.89492, saving model to effnet.keras
# 83/83 [==============================] - 12s 150ms/step - loss: 0.1283 - accuracy: 0.9578 - val_loss: 0.3284 - val_accuracy: 0.8949 - lr: 0.0010
# Epoch 4/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9645
# Epoch 4: val_accuracy improved from 0.89492 to 0.95254, saving model to effnet.keras
# 83/83 [==============================] - 12s 149ms/step - loss: 0.1043 - accuracy: 0.9645 - val_loss: 0.1655 - val_accuracy: 0.9525 - lr: 0.0010
# Epoch 5/5
# 83/83 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9732
# Epoch 5: val_accuracy improved from 0.95254 to 0.97966, saving model to effnet.keras
# 83/83 [==============================] - 12s 147ms/step - loss: 0.0861 - accuracy: 0.9732 - val_loss: 0.0655 - val_accuracy: 0.9797 - lr: 0.0010

# %%
filterwarnings('ignore')

epochs = [i for i in range(5)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', fontname='monospace',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss,label ='Training Loss')
ax[1].plot(epochs, val_loss, label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)

# %%
print(classification_report(y_test_new,pred))

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,alpha=0.7,linewidths=2)
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',y=0.92,x=0.28,alpha=0.8)

plt.show()

# %% [markdown]
# **Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout

# Create a new sequential model for RNN
model_rnn = Sequential()

# Add a SimpleRNN layer with 64 units
model_rnn.add(SimpleRNN(64, input_shape=(10, 1)))  # Input shape: (sequence_length, input_dim)
model_rnn.add(Dropout(0.2))

# Add a Dense layer for classification
model_rnn.add(Dense(128, activation='relu'))
model_rnn.add(Dense(64, activation='relu'))
model_rnn.add(Dense(4, activation='softmax'))  # Adjust the number of units for your specific classification problem

# Compile the model
model_rnn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model_rnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 21060 (82.27 KB)
# Trainable params: 21060 (82.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout, Flatten, Reshape # Import Reshape
from tensorflow.keras.optimizers import Adam

# Create a new sequential model for RNN
model_rnn = Sequential()

# Flatten each image into a single vector
model_rnn.add(Flatten(input_shape=(224, 224, 3)))

# Reshape to fit the RNN input shape (sequence_length, input_dim)
model_rnn.add(Dense(10, activation='relu'))  # Adjust `10` based on your sequence length
model_rnn.add(Reshape((10, 1)))  # Reshape to (sequence_length, input_dim)

# Add a SimpleRNN layer with 64 units
model_rnn.add(SimpleRNN(64))

# Add Dropout for regularization
model_rnn.add(Dropout(0.2))

# Add Dense layers for classification
model_rnn.add(Dense(128, activation='relu'))
model_rnn.add(Dense(64, activation='relu'))
model_rnn.add(Dense(4, activation='softmax'))  # Adjust the number of units for your specific classification problem

# Compile the model
model_rnn.compile(optimizer=Adam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model_rnn.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 150528)            0
#
#  dense_5 (Dense)             (None, 10)                1505290
#
#  reshape (Reshape)           (None, 10, 1)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 64)                4224
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 128)               8320
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 1526350 (5.82 MB)
# Trainable params: 1526350 (5.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Display the plot of the model architecture
plot_model(model_rnn, show_shapes=True, dpi=150)

# %%
plot_model(model_rnn, show_shapes=True, dpi=150)

# Display the plot
plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
resized_X_train = []
for img in X_train:
    resized_img = cv2.resize(img, (224, 224))
    resized_X_train.append(resized_img)

resized_X_train = np.array(resized_X_train)

resized_X_test = []
for img in X_test:
    resized_img = cv2.resize(img, (224, 224))
    resized_X_test.append(resized_img)

resized_X_test = np.array(resized_X_test)

# %%
model_rnn.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
history = model_rnn.fit(resized_X_train,y_train,validation_split=0.1, epochs =30, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/30
# 80/83 [===========================>..] - ETA: 0s - loss: 1.3576 - accuracy: 0.2855
# Epoch 1: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 2s 25ms/step - loss: 1.3586 - accuracy: 0.2867 - val_loss: 1.3592 - val_accuracy: 0.2915 - lr: 8.1000e-06
# Epoch 2/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3592 - accuracy: 0.2843
# Epoch 2: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3587 - accuracy: 0.2852 - val_loss: 1.3592 - val_accuracy: 0.2915 - lr: 8.1000e-06
# Epoch 3/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3604 - accuracy: 0.2797
# Epoch 3: val_accuracy did not improve from 0.97966
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3598 - accuracy: 0.2806 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 8.1000e-06
# Epoch 4/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3585 - accuracy: 0.2908
# Epoch 4: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3585 - accuracy: 0.2908 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 2.4300e-06
# Epoch 5/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3595 - accuracy: 0.2954
# Epoch 5: val_accuracy did not improve from 0.97966
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3595 - accuracy: 0.2954 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 2.4300e-06
# Epoch 6/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3599 - accuracy: 0.2778
# Epoch 6: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3595 - accuracy: 0.2776 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 7.2900e-07
# Epoch 7/30
# 80/83 [===========================>..] - ETA: 0s - loss: 1.3607 - accuracy: 0.2816
# Epoch 7: val_accuracy did not improve from 0.97966
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 83/83 [==============================] - 1s 15ms/step - loss: 1.3598 - accuracy: 0.2825 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 7.2900e-07
# Epoch 8/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3604 - accuracy: 0.2873
# Epoch 8: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3605 - accuracy: 0.2867 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 2.1870e-07
# Epoch 9/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3584 - accuracy: 0.2803
# Epoch 9: val_accuracy did not improve from 0.97966
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# 83/83 [==============================] - 3s 31ms/step - loss: 1.3584 - accuracy: 0.2803 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 2.1870e-07
# Epoch 10/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3597 - accuracy: 0.2810
# Epoch 10: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 3s 37ms/step - loss: 1.3597 - accuracy: 0.2810 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 6.5610e-08
# Epoch 11/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3586 - accuracy: 0.2878
# Epoch 11: val_accuracy did not improve from 0.97966
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# 83/83 [==============================] - 3s 31ms/step - loss: 1.3586 - accuracy: 0.2878 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 6.5610e-08
# Epoch 12/30
# 81/83 [============================>.] - ETA: 0s - loss: 1.3566 - accuracy: 0.2886
# Epoch 12: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 2s 26ms/step - loss: 1.3583 - accuracy: 0.2856 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.9683e-08
# Epoch 13/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3588 - accuracy: 0.2809
# Epoch 13: val_accuracy did not improve from 0.97966
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3589 - accuracy: 0.2822 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.9683e-08
# Epoch 14/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3570 - accuracy: 0.2961
# Epoch 14: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 2s 19ms/step - loss: 1.3583 - accuracy: 0.2961 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 5.9049e-09
# Epoch 15/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3588 - accuracy: 0.2791
# Epoch 15: val_accuracy did not improve from 0.97966
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# 83/83 [==============================] - 4s 54ms/step - loss: 1.3588 - accuracy: 0.2791 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 5.9049e-09
# Epoch 16/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3603 - accuracy: 0.2769
# Epoch 16: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 4s 44ms/step - loss: 1.3603 - accuracy: 0.2769 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.7715e-09
# Epoch 17/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3579 - accuracy: 0.2916
# Epoch 17: val_accuracy did not improve from 0.97966
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# 83/83 [==============================] - 4s 46ms/step - loss: 1.3579 - accuracy: 0.2916 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.7715e-09
# Epoch 18/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3592 - accuracy: 0.2810
# Epoch 18: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 3s 39ms/step - loss: 1.3592 - accuracy: 0.2810 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 5.3144e-10
# Epoch 19/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3598 - accuracy: 0.2763
# Epoch 19: val_accuracy did not improve from 0.97966
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.5943230069481729e-10.
# 83/83 [==============================] - 4s 47ms/step - loss: 1.3599 - accuracy: 0.2754 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 5.3144e-10
# Epoch 20/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3591 - accuracy: 0.2912
# Epoch 20: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 3s 38ms/step - loss: 1.3591 - accuracy: 0.2912 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.5943e-10
# Epoch 21/30
# 81/83 [============================>.] - ETA: 0s - loss: 1.3568 - accuracy: 0.2971
# Epoch 21: val_accuracy did not improve from 0.97966
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.7829690208445185e-11.
# 83/83 [==============================] - 3s 32ms/step - loss: 1.3576 - accuracy: 0.2957 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.5943e-10
# Epoch 22/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3594 - accuracy: 0.2923
# Epoch 22: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 3s 33ms/step - loss: 1.3594 - accuracy: 0.2923 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 4.7830e-11
# Epoch 23/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3600 - accuracy: 0.2732
# Epoch 23: val_accuracy did not improve from 0.97966
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.434890747886719e-11.
# 83/83 [==============================] - 3s 36ms/step - loss: 1.3604 - accuracy: 0.2727 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 4.7830e-11
# Epoch 24/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3587 - accuracy: 0.2862
# Epoch 24: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 3s 31ms/step - loss: 1.3594 - accuracy: 0.2852 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.4349e-11
# Epoch 25/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3585 - accuracy: 0.2881
# Epoch 25: val_accuracy did not improve from 0.97966
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.304672243660157e-12.
# 83/83 [==============================] - 2s 20ms/step - loss: 1.3584 - accuracy: 0.2889 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.4349e-11
# Epoch 26/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3581 - accuracy: 0.2873
# Epoch 26: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 3s 32ms/step - loss: 1.3585 - accuracy: 0.2882 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 4.3047e-12
# Epoch 27/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3599 - accuracy: 0.2710
# Epoch 27: val_accuracy did not improve from 0.97966
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.2914016210563428e-12.
# 83/83 [==============================] - 3s 32ms/step - loss: 1.3598 - accuracy: 0.2712 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 4.3047e-12
# Epoch 28/30
# 82/83 [============================>.] - ETA: 0s - loss: 1.3586 - accuracy: 0.2904
# Epoch 28: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 1s 17ms/step - loss: 1.3593 - accuracy: 0.2897 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.2914e-12
# Epoch 29/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3589 - accuracy: 0.2806
# Epoch 29: val_accuracy did not improve from 0.97966
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.874204993273289e-13.
# 83/83 [==============================] - 1s 16ms/step - loss: 1.3589 - accuracy: 0.2806 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 1.2914e-12
# Epoch 30/30
# 83/83 [==============================] - ETA: 0s - loss: 1.3598 - accuracy: 0.2859
# Epoch 30: val_accuracy did not improve from 0.97966
# 83/83 [==============================] - 4s 44ms/step - loss: 1.3598 - accuracy: 0.2859 - val_loss: 1.3591 - val_accuracy: 0.2915 - lr: 3.8742e-13

# %%
filterwarnings('ignore')

epochs = [i for i in range(30)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', fontname='monospace',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss,label ='Training Loss')
ax[1].plot(epochs, val_loss, label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model_rnn.predict(resized_X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 1s 7ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        97
#            1       0.00      0.00      0.00        51
#            2       0.27      1.00      0.43        89
#            3       0.00      0.00      0.00        91
#
#     accuracy                           0.27       328
#    macro avg       0.07      0.25      0.11       328
# weighted avg       0.07      0.27      0.12       328

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,alpha=0.7,linewidths=2)
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',y=0.92,x=0.28,alpha=0.8)

plt.show()

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))
    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(150,150))
    img = img.reshape(1,150,150,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))

# %%
model.save("/content/drive/MyDrive/MRI_classification_saved/brain_rnn.h5")
