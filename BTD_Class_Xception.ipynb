# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
from tensorflow.keras.utils import plot_model
from keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D,BatchNormalization, Flatten, Dense, Dropout

# %%
labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/MRI BTD Classification dataset','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/MRI BTD Classification dataset','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:24<00:00, 33.93it/s]
# 100%|██████████| 395/395 [00:10<00:00, 36.95it/s]
# 100%|██████████| 822/822 [00:24<00:00, 33.19it/s]
# 100%|██████████| 837/837 [00:29<00:00, 28.13it/s]
# 100%|██████████| 100/100 [00:04<00:00, 23.16it/s]
# 100%|██████████| 105/105 [00:03<00:00, 33.75it/s]
# 100%|██████████| 115/115 [00:03<00:00, 32.76it/s]
# 100%|██████████| 74/74 [00:45<00:00,  1.62it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
X_train.shape
# Out:
# (2946, 150, 150, 3)

# %%
X_test.shape
# Out:
# (328, 150, 150, 3)

# %%
y_train.shape
# Out:
# (2946,)

# %%
y_test.shape
# Out:
# (328,)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
y_test_labels = np.argmax(y_test, axis=1)

# Find unique class labels
unique_labels = np.unique(y_test_labels)

print("Unique class labels:", unique_labels)
# Out:
# Unique class labels: [0 1 2 3]

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001, mode='auto',verbose=1)

# %%
plot_model(model, show_shapes=True, dpi=150)

# Display the plot
plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.787384 to fit

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =5, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/5
# 83/83 [==============================] - ETA: 0s - loss: 0.4813 - accuracy: 0.8303
# Epoch 1: val_accuracy improved from -inf to 0.93559, saving model to effnet.keras
# 83/83 [==============================] - 73s 254ms/step - loss: 0.4813 - accuracy: 0.8303 - val_loss: 0.2547 - val_accuracy: 0.9356 - lr: 0.0010
# Epoch 2/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1964 - accuracy: 0.9313
# Epoch 2: val_accuracy improved from 0.93559 to 0.94576, saving model to effnet.keras
# 83/83 [==============================] - 13s 157ms/step - loss: 0.1964 - accuracy: 0.9313 - val_loss: 0.1684 - val_accuracy: 0.9458 - lr: 0.0010
# Epoch 3/5
# 83/83 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.9661
# Epoch 3: val_accuracy did not improve from 0.94576
# 83/83 [==============================] - 11s 136ms/step - loss: 0.0996 - accuracy: 0.9661 - val_loss: 0.4577 - val_accuracy: 0.8814 - lr: 0.0010
# Epoch 4/5
# 83/83 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9657
# Epoch 4: val_accuracy did not improve from 0.94576
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 11s 135ms/step - loss: 0.0956 - accuracy: 0.9657 - val_loss: 2.0164 - val_accuracy: 0.5831 - lr: 0.0010
# Epoch 5/5
# 83/83 [==============================] - ETA: 0s - loss: 0.0615 - accuracy: 0.9777
# Epoch 5: val_accuracy improved from 0.94576 to 0.95593, saving model to effnet.keras
# 83/83 [==============================] - 12s 148ms/step - loss: 0.0615 - accuracy: 0.9777 - val_loss: 0.1424 - val_accuracy: 0.9559 - lr: 3.0000e-04

# %%
filterwarnings('ignore')

epochs = [i for i in range(5)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', fontname='monospace',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss,label ='Training Loss')
ax[1].plot(epochs, val_loss, label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 3s 125ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93        97
#            1       0.89      0.98      0.93        51
#            2       0.99      0.87      0.92        89
#            3       0.99      0.98      0.98        91
#
#     accuracy                           0.94       328
#    macro avg       0.94      0.95      0.94       328
# weighted avg       0.95      0.94      0.94       328

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,alpha=0.7,linewidths=2)
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',y=0.92,x=0.28,alpha=0.8)

plt.show()

# %% [markdown]
# **Model**

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Load the Xception model pre-trained on ImageNet data
xception_model = Xception(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Create a new model
model_xception = Sequential()

# Add the Xception convolutional base model
model_xception.add(xception_model)

# Add layers on top of the Xception base model
model_xception.add(Flatten())
model_xception.add(Dense(128, activation='relu'))
model_xception.add(Dropout(0.2))
model_xception.add(Dense(64, activation='relu'))
model_xception.add(Dense(4, activation='softmax'))  # Adjust the number of units for your specific classification problem

# Freeze the Xception layers so they are not trainable
xception_model.trainable = False

# Compile the model
model_xception.compile(optimizer=Adam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model_xception.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense_1 (Dense)             (None, 128)               12845184
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 33715180 (128.61 MB)
# Trainable params: 12853700 (49.03 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
plot_model(model_xception, show_shapes=True, dpi=150)

# Display the plot
plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
resized_X_train = []
for img in X_train:
    resized_img = cv2.resize(img, (224, 224))
    resized_X_train.append(resized_img)

resized_X_train = np.array(resized_X_train)

resized_X_test = []
for img in X_test:
    resized_img = cv2.resize(img, (224, 224))
    resized_X_test.append(resized_img)

resized_X_test = np.array(resized_X_test)

# %%
model_xception.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
history = model_xception.fit(resized_X_train,y_train,validation_split=0.1, epochs =10, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/10
# 83/83 [==============================] - ETA: 0s - loss: 11.1569 - accuracy: 0.4659
# Epoch 1: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 31s 269ms/step - loss: 11.1569 - accuracy: 0.4659 - val_loss: 2.9385 - val_accuracy: 0.4644 - lr: 0.0010
# Epoch 2/10
# 83/83 [==============================] - ETA: 0s - loss: 1.7723 - accuracy: 0.4738
# Epoch 2: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 16s 198ms/step - loss: 1.7723 - accuracy: 0.4738 - val_loss: 1.1373 - val_accuracy: 0.5220 - lr: 0.0010
# Epoch 3/10
# 83/83 [==============================] - ETA: 0s - loss: 1.1350 - accuracy: 0.4908
# Epoch 3: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 16s 188ms/step - loss: 1.1350 - accuracy: 0.4908 - val_loss: 1.1065 - val_accuracy: 0.5254 - lr: 0.0010
# Epoch 4/10
# 83/83 [==============================] - ETA: 0s - loss: 0.9632 - accuracy: 0.5436
# Epoch 4: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 14s 170ms/step - loss: 0.9632 - accuracy: 0.5436 - val_loss: 0.9282 - val_accuracy: 0.6441 - lr: 0.0010
# Epoch 5/10
# 83/83 [==============================] - ETA: 0s - loss: 0.9206 - accuracy: 0.5968
# Epoch 5: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 14s 170ms/step - loss: 0.9206 - accuracy: 0.5968 - val_loss: 0.8526 - val_accuracy: 0.6102 - lr: 0.0010
# Epoch 6/10
# 83/83 [==============================] - ETA: 0s - loss: 0.9226 - accuracy: 0.5994
# Epoch 6: val_accuracy did not improve from 0.95593
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 14s 174ms/step - loss: 0.9226 - accuracy: 0.5994 - val_loss: 0.8149 - val_accuracy: 0.6271 - lr: 0.0010
# Epoch 7/10
# 83/83 [==============================] - ETA: 0s - loss: 0.7543 - accuracy: 0.6432
# Epoch 7: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 16s 188ms/step - loss: 0.7543 - accuracy: 0.6432 - val_loss: 0.8001 - val_accuracy: 0.6576 - lr: 3.0000e-04
# Epoch 8/10
# 83/83 [==============================] - ETA: 0s - loss: 0.6658 - accuracy: 0.6797
# Epoch 8: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 14s 173ms/step - loss: 0.6658 - accuracy: 0.6797 - val_loss: 0.7251 - val_accuracy: 0.6949 - lr: 3.0000e-04
# Epoch 9/10
# 83/83 [==============================] - ETA: 0s - loss: 0.6423 - accuracy: 0.6820
# Epoch 9: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 16s 189ms/step - loss: 0.6423 - accuracy: 0.6820 - val_loss: 0.7172 - val_accuracy: 0.6915 - lr: 3.0000e-04
# Epoch 10/10
# 83/83 [==============================] - ETA: 0s - loss: 0.5982 - accuracy: 0.7122
# Epoch 10: val_accuracy did not improve from 0.95593
# 83/83 [==============================] - 15s 176ms/step - loss: 0.5982 - accuracy: 0.7122 - val_loss: 0.6778 - val_accuracy: 0.7017 - lr: 3.0000e-04

# %%
filterwarnings('ignore')

epochs = [i for i in range(10)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', fontname='monospace',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss,label ='Training Loss')
ax[1].plot(epochs, val_loss, label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model_xception.predict(resized_X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 4s 300ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.65      0.72        97
#            1       0.93      0.55      0.69        51
#            2       0.64      0.69      0.66        89
#            3       0.67      0.92      0.77        91
#
#     accuracy                           0.72       328
#    macro avg       0.77      0.70      0.71       328
# weighted avg       0.75      0.72      0.72       328

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,alpha=0.7,linewidths=2)
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',y=0.92,x=0.28,alpha=0.8)

plt.show()

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))
    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(150,150))
    img = img.reshape(1,150,150,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))

# %%
model.save("/content/drive/MyDrive/MRI_classification_saved/brain_Xception.h5")
