# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
from tensorflow.keras.utils import plot_model
from keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D,BatchNormalization, Flatten, Dense, Dropout

# %%
labels = ['glioma_tumor', 'no_tumor', 'meningioma_tumor', 'pituitary_tumor']

X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/MRI BTD Classification dataset','Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('/content/drive/MyDrive/MRI BTD Classification dataset','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)

X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:28<00:00, 28.61it/s]
# 100%|██████████| 395/395 [00:09<00:00, 41.55it/s]
# 100%|██████████| 822/822 [00:27<00:00, 30.43it/s]
# 100%|██████████| 837/837 [00:26<00:00, 32.03it/s]
# 100%|██████████| 100/100 [00:04<00:00, 22.32it/s]
# 100%|██████████| 105/105 [00:03<00:00, 28.43it/s]
# 100%|██████████| 115/115 [00:04<00:00, 28.58it/s]
# 100%|██████████| 74/74 [00:48<00:00,  1.53it/s]

# %%
k=0
fig, ax = plt.subplots(1,4,figsize=(20,20))
fig.text(s='Sample Image From Each Label',size=18,fontweight='bold',
             fontname='monospace',y=0.62,x=0.4,alpha=0.8)
for i in labels:
    j=0
    while True :
        if y_train[j]==i:
            ax[k].imshow(X_train[j])
            ax[k].set_title(y_train[j])
            ax[k].axis('off')
            k+=1
            break
        j+=1

# %%
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
X_train.shape
# Out:
# (2946, 150, 150, 3)

# %%
X_test.shape
# Out:
# (328, 150, 150, 3)

# %%
y_train.shape
# Out:
# (2946,)

# %%
y_test.shape
# Out:
# (328,)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)


y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
y_test_labels = np.argmax(y_test, axis=1)

# Find unique class labels
unique_labels = np.unique(y_test_labels)

print("Unique class labels:", unique_labels)
# Out:
# Unique class labels: [0 1 2 3]

# %%
effnet = EfficientNetB0(weights='imagenet',include_top=False,input_shape=(image_size,image_size,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step

# %%
model = effnet.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dropout(rate=0.5)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=effnet.input, outputs = model)

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
tensorboard = TensorBoard(log_dir = 'logs')
checkpoint = ModelCheckpoint("effnet.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001, mode='auto',verbose=1)

# %%
plot_model(model, show_shapes=True, dpi=150)

# Display the plot
plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.787384 to fit

# %%
history = model.fit(X_train,y_train,validation_split=0.1, epochs =5, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/5
# 83/83 [==============================] - ETA: 0s - loss: 0.4542 - accuracy: 0.8374
# Epoch 1: val_accuracy improved from -inf to 0.84068, saving model to effnet.keras
# 83/83 [==============================] - 76s 230ms/step - loss: 0.4542 - accuracy: 0.8374 - val_loss: 0.5214 - val_accuracy: 0.8407 - lr: 0.0010
# Epoch 2/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9389
# Epoch 2: val_accuracy improved from 0.84068 to 0.92203, saving model to effnet.keras
# 83/83 [==============================] - 14s 172ms/step - loss: 0.1793 - accuracy: 0.9389 - val_loss: 0.1795 - val_accuracy: 0.9220 - lr: 0.0010
# Epoch 3/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9608
# Epoch 3: val_accuracy improved from 0.92203 to 0.93220, saving model to effnet.keras
# 83/83 [==============================] - 16s 189ms/step - loss: 0.1116 - accuracy: 0.9608 - val_loss: 0.3511 - val_accuracy: 0.9322 - lr: 0.0010
# Epoch 4/5
# 83/83 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9649
# Epoch 4: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 13s 161ms/step - loss: 0.0968 - accuracy: 0.9649 - val_loss: 0.3241 - val_accuracy: 0.9119 - lr: 0.0010
# Epoch 5/5
# 83/83 [==============================] - ETA: 0s - loss: 0.1064 - accuracy: 0.9661
# Epoch 5: val_accuracy did not improve from 0.93220
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 13s 161ms/step - loss: 0.1064 - accuracy: 0.9661 - val_loss: 0.2142 - val_accuracy: 0.9254 - lr: 0.0010

# %%
filterwarnings('ignore')

epochs = [i for i in range(5)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', fontname='monospace',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss,label ='Training Loss')
ax[1].plot(epochs, val_loss, label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model.predict(X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 4s 156ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        97
#            1       0.96      1.00      0.98        51
#            2       0.98      0.94      0.96        89
#            3       0.99      1.00      0.99        91
#
#     accuracy                           0.97       328
#    macro avg       0.97      0.98      0.97       328
# weighted avg       0.97      0.97      0.97       328

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,alpha=0.7,linewidths=2)
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',y=0.92,x=0.28,alpha=0.8)

plt.show()

# %% [markdown]
# **Model**

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Load the DenseNet121 model pre-trained on ImageNet data
densenet_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Create a new model
model_densenet = Sequential()

# Add the DenseNet convolutional base model
model_densenet.add(densenet_model)

# Add layers on top of the DenseNet base model
model_densenet.add(Flatten())
model_densenet.add(Dense(128, activation='relu'))
model_densenet.add(Dropout(0.2))
model_densenet.add(Dense(64, activation='relu'))
model_densenet.add(Dense(4, activation='softmax'))  # Adjust the number of units for your specific classification problem

# Freeze the DenseNet layers so they are not trainable
densenet_model.trainable = False

# Compile the model
model_densenet.compile(optimizer=Adam(lr=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print a summary of the model architecture
model_densenet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense_1 (Dense)             (None, 128)               6422656
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 13468676 (51.38 MB)
# Trainable params: 6431172 (24.53 MB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %%
plot_model(model_densenet, show_shapes=True, dpi=150)

# Display the plot
plt.figure(figsize=(20, 10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
resized_X_train = []
for img in X_train:
    resized_img = cv2.resize(img, (224, 224))
    resized_X_train.append(resized_img)

resized_X_train = np.array(resized_X_train)

resized_X_test = []
for img in X_test:
    resized_img = cv2.resize(img, (224, 224))
    resized_X_test.append(resized_img)

resized_X_test = np.array(resized_X_test)

# %%
model_densenet.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
history = model_densenet.fit(resized_X_train,y_train,validation_split=0.1, epochs =10, verbose=1, batch_size=32,
                   callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/10
# 83/83 [==============================] - ETA: 0s - loss: 7.2781 - accuracy: 0.5157
# Epoch 1: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 41s 306ms/step - loss: 7.2781 - accuracy: 0.5157 - val_loss: 1.2134 - val_accuracy: 0.7085 - lr: 0.0010
# Epoch 2/10
# 83/83 [==============================] - ETA: 0s - loss: 0.9807 - accuracy: 0.6213
# Epoch 2: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 9s 108ms/step - loss: 0.9807 - accuracy: 0.6213 - val_loss: 0.6183 - val_accuracy: 0.7356 - lr: 0.0010
# Epoch 3/10
# 83/83 [==============================] - ETA: 0s - loss: 0.7143 - accuracy: 0.6967
# Epoch 3: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 9s 113ms/step - loss: 0.7143 - accuracy: 0.6967 - val_loss: 0.5418 - val_accuracy: 0.7932 - lr: 0.0010
# Epoch 4/10
# 83/83 [==============================] - ETA: 0s - loss: 0.6800 - accuracy: 0.6907
# Epoch 4: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 10s 117ms/step - loss: 0.6800 - accuracy: 0.6907 - val_loss: 0.5299 - val_accuracy: 0.7797 - lr: 0.0010
# Epoch 5/10
# 83/83 [==============================] - ETA: 0s - loss: 0.7182 - accuracy: 0.6809
# Epoch 5: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 9s 112ms/step - loss: 0.7182 - accuracy: 0.6809 - val_loss: 0.5332 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 6/10
# 83/83 [==============================] - ETA: 0s - loss: 0.6273 - accuracy: 0.7265
# Epoch 6: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 9s 110ms/step - loss: 0.6273 - accuracy: 0.7265 - val_loss: 0.5365 - val_accuracy: 0.8407 - lr: 0.0010
# Epoch 7/10
# 83/83 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.7646
# Epoch 7: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 10s 120ms/step - loss: 0.5734 - accuracy: 0.7646 - val_loss: 0.4419 - val_accuracy: 0.8814 - lr: 0.0010
# Epoch 8/10
# 83/83 [==============================] - ETA: 0s - loss: 0.5013 - accuracy: 0.7918
# Epoch 8: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 9s 103ms/step - loss: 0.5013 - accuracy: 0.7918 - val_loss: 0.5281 - val_accuracy: 0.8169 - lr: 0.0010
# Epoch 9/10
# 83/83 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.7857
# Epoch 9: val_accuracy did not improve from 0.93220
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 83/83 [==============================] - 9s 108ms/step - loss: 0.5038 - accuracy: 0.7857 - val_loss: 0.3702 - val_accuracy: 0.8678 - lr: 0.0010
# Epoch 10/10
# 83/83 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.8163
# Epoch 10: val_accuracy did not improve from 0.93220
# 83/83 [==============================] - 9s 109ms/step - loss: 0.4390 - accuracy: 0.8163 - val_loss: 0.3527 - val_accuracy: 0.8780 - lr: 3.0000e-04

# %%
filterwarnings('ignore')

epochs = [i for i in range(10)]
fig, ax = plt.subplots(1,2,figsize=(14,7))
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']

fig.text(s='Epochs vs. Training and Validation Accuracy/Loss',size=18,fontweight='bold', fontname='monospace',y=1,x=0.28,alpha=0.8)

sns.despine()
ax[0].plot(epochs, train_acc, label = 'Training Accuracy')
ax[0].plot(epochs, val_acc, label = 'Validation Accuracy')
ax[0].legend(frameon=False)
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')

sns.despine()
ax[1].plot(epochs, train_loss,label ='Training Loss')
ax[1].plot(epochs, val_loss, label = 'Validation Loss')
ax[1].legend(frameon=False)
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Training & Validation Loss')

fig.show()

# %%
pred = model_densenet.predict(resized_X_test)
pred = np.argmax(pred,axis=1)
y_test_new = np.argmax(y_test,axis=1)
# Out:
# 11/11 [==============================] - 6s 362ms/step

# %%
print(classification_report(y_test_new,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.89      0.81        97
#            1       0.91      0.96      0.93        51
#            2       0.86      0.62      0.72        89
#            3       0.95      0.98      0.96        91
#
#     accuracy                           0.85       328
#    macro avg       0.86      0.86      0.86       328
# weighted avg       0.86      0.85      0.85       328

# %%
fig,ax=plt.subplots(1,1,figsize=(14,7))
sns.heatmap(confusion_matrix(y_test_new,pred),ax=ax,xticklabels=labels,yticklabels=labels,annot=True,alpha=0.7,linewidths=2)
fig.text(s='Heatmap of the Confusion Matrix',size=18,fontweight='bold',
             fontname='monospace',y=0.92,x=0.28,alpha=0.8)

plt.show()

# %%
def img_pred(upload):
    for name, file_info in uploader.value.items():
        img = Image.open(io.BytesIO(file_info['content']))
    opencvImage = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    img = cv2.resize(opencvImage,(150,150))
    img = img.reshape(1,150,150,3)
    p = model.predict(img)
    p = np.argmax(p,axis=1)[0]

    if p==0:
        p='Glioma Tumor'
    elif p==1:
        print('The model predicts that there is no tumor')
    elif p==2:
        p='Meningioma Tumor'
    else:
        p='Pituitary Tumor'

    if p!=1:
        print(f'The Model predicts that it is a {p}')

# %%
uploader = widgets.FileUpload()
display(uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
button = widgets.Button(description='Predict')
out = widgets.Output()
def on_button_clicked(_):
    with out:
        clear_output()
        try:
            img_pred(uploader)

        except:
            print('No Image Uploaded/Invalid Image File')
button.on_click(on_button_clicked)
widgets.VBox([button,out])
# Out:
# VBox(children=(Button(description='Predict', style=ButtonStyle()), Output()))

# %%
model.save("/content/drive/MyDrive/MRI_classification_saved/brain_densenet.h5")
